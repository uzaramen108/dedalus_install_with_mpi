# %%
# --------------------------------------------------
# 1️⃣ Mount Google Drive (optional, for cache)
# --------------------------------------------------
from google.colab import drive
import os

if not os.path.ismount("/content/drive"):
    drive.mount("/content/drive")
else:
    print("📦 Google Drive already mounted")

# --------------------------------------------------
# 2️⃣ Clone dedalus-colab repository (idempotent)
# --------------------------------------------------
from pathlib import Path
import subprocess

REPO_URL = "https://github.com/uzaramen108/dedalus-colab.git"
ROOT = Path("/content")
REPO_DIR = ROOT / "dedalus-colab"

def run(cmd):
    #print("$", " ".join(map(str, cmd)))
    subprocess.run(cmd, check=True)

if not REPO_DIR.exists():
    print("📥 Cloning dedalus-colab...")
    run(["git", "clone", REPO_URL, str(REPO_DIR)])
elif not (REPO_DIR / ".git").exists():
    raise RuntimeError("Directory exists but is not a git repository")
else:
    print("📦 Repository already exists — skipping clone")

# --------------------------------------------------
# 3️⃣ Run setup_dedalus.py IN THIS KERNEL (CRITICAL)
# --------------------------------------------------
print("🚀 Running setup_dedalus.py in current kernel")

USE_CLEAN = False  # <--- Set True to remove existing environment
opts = "--clean" if USE_CLEAN else ""

get_ipython().run_line_magic(
    "run", f"{REPO_DIR / 'setup_dedalus.py'} {opts}"
)

# ==================================================
# 4️⃣ Sanity check
# ==================================================
try:
    get_ipython().run_cell_magic('dedalus', '--info -np 4', '')
except Exception as e:
    print("⚠️ %%dedalus magic not found:", e)
# Out:
# 📦 Google Drive already mounted
# 📦 Repository already exists — skipping clone
# 🚀 Running setup_dedalus.py in current kernel
# 📦 Google Drive detected — using persistent cache
# 🔧 Installing dedalus environment...
# ✨ Loading dedalus Jupyter magic... %%dedalus registered
#
# 🐍 Python          : 3.13.11
# 📦 dedalus         : 3.0.4
# 💻 Platform        : Linux-6.6.105+-x86_64-with-glibc2.35
# 🧵 Running as root : True
#
# 🔎 dedalus runtime info
# -----------------------
# Environment        : dedalus
# micromamba         : /content/micromamba/bin/micromamba
# MPI implementation : OPENMPI
# MPI version        : mpiexec (OpenRTE) 4.1.2
# MPI ranks (-np)    : 4

# %% [markdown]
# 아래 스크립트는 dedalus가 제대로 설치되었는지에 대한 테스트용 스크립트입니다.

# %%
# %%dedalus
# """
# Dedalus script solving for the eigenvalues of the Mathieu equation. This script
# demonstrates solving a periodic eigenvalue problem with nonconstant coefficients
# and produces a plot of the Mathieu eigenvalues 'a' as a function of the
# parameter 'q'. It should take just a few seconds to run (serial only).
#
# We use a Fourier basis to solve the EVP:
#     dx(dx(y)) + (a - 2*q*cos(2*x))*y = 0
# where 'a' is the eigenvalue. Periodicity is enforced by using the Fourier basis.
#
# To run and plot:
#     $ python3 mathieu_evp.py
# """
#
# import os
# if 'MPLBACKEND' in os.environ:
#     del os.environ['MPLBACKEND'] # Colab이 강제로 주입한 호환되지 않는 백엔드 설정 제거
# import numpy as np
# import matplotlib.pyplot as plt
# from mpi4py import MPI
# import dedalus.public as d3
# import logging
# logger = logging.getLogger(__name__)
#
#
# # Parameters
# N = 32
# q_list = np.linspace(0, 30, 100)
#
# # Basis
# coord = d3.Coordinate('x')
# dist = d3.Distributor(coord, dtype=np.complex128)
# basis = d3.ComplexFourier(coord, N, bounds=(0, 2*np.pi))
#
# # Fields
# y = dist.Field(bases=basis)
# a = dist.Field()
#
# # Substitutions
# x = dist.local_grid(basis)
# q = dist.Field()
# cos_2x = dist.Field(bases=basis)
# cos_2x['g'] = np.cos(2 * x)
# dx = lambda A: d3.Differentiate(A, coord)
#
# # Problem
# problem = d3.EVP([y], eigenvalue=a, namespace=locals())
# problem.add_equation("dx(dx(y)) + (a - 2*q*cos_2x)*y = 0")
#
# # Solver
# comm = MPI.COMM_WORLD
# if comm.rank == 0:
#     solver = problem.build_solver()
#     evals = []
#     for qi in q_list:
#         q['g'] = qi
#         solver.solve_dense(solver.subproblems[0], rebuild_matrices=True)
#         sorted_evals = np.sort(solver.eigenvalues.real)
#         evals.append(sorted_evals[:10])
#     evals = np.array(evals)
#
#     # Plot
#     fig = plt.figure(figsize=(6, 4))
#     plt.plot(q_list, evals[:, 0::2], '.-', c='C0')
#     plt.plot(q_list, evals[:, 1::2], '.-', c='C1')
#     plt.xlim(q_list.min(), q_list.max())
#     plt.ylim(-10, 30)
#     plt.xlabel("q")
#     plt.ylabel("eigenvalues")
#     plt.title("Mathieu eigenvalues")
#     plt.tight_layout()
#     plt.savefig("mathieu_eigenvalues.png", dpi=200)
# Out:
# 2026-01-07 05:23:32,693 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 5.0e+01/s
# 2026-01-07 05:23:32,710 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 6.7e+01/s
# 2026-01-07 05:23:32,727 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 7.4e+01/s
# 2026-01-07 05:23:32,741 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 8.5e+01/s
# 2026-01-07 05:23:32,754 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 9.7e+01/s
# 2026-01-07 05:23:32,770 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 8.2e+01/s
# 2026-01-07 05:23:32,785 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 7.9e+01/s
# 2026-01-07 05:23:32,797 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 9.7e+01/s
# 2026-01-07 05:23:32,815 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 6.8e+01/s
# 2026-01-07 05:23:32,828 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 1.0e+02/s
# 2026-01-07 05:23:32,843 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 8.5e+01/s
# 2026-01-07 05:23:32,859 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 7.4e+01/s
# 2026-01-07 05:23:32,872 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 1.0e+02/s
# 2026-01-07 05:23:32,886 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 9.2e+01/s
# 2026-01-07 05:23:32,900 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 8.7e+01/s
# 2026-01-07 05:23:32,915 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 9.4e+01/s
# 2026-01-07 05:23:32,929 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 8.8e+01/s
# 2026-01-07 05:23:32,943 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 9.2e+01/s
# 2026-01-07 05:23:32,956 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 1.0e+02/s
# 2026-01-07 05:23:32,969 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 9.7e+01/s
# 2026-01-07 05:23:32,984 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 9.4e+01/s
# 2026-01-07 05:23:33,000 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 7.7e+01/s
# 2026-01-07 05:23:33,014 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 8.6e+01/s
# 2026-01-07 05:23:33,031 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 7.3e+01/s
# 